# %%
import ODE_single_pendulum as sp

# %%
model = sp.single_pendulum()

# %%
model.EulerForward()

# %%
model.Leapfrog()
# Out:
# Predict using Euler Forward for Leapfrog? "yes" or "no": yes

# %%
model.Leapfrog()
# Out:
# Predict using Euler Forward for Leapfrog? "yes" or "no": no

# %%
model.EulerBackward()

# %%
model.RK4()

# %%
model.Energy()

# %%
model.period('EulerForward')
# Out:
# x-intercept at:
#  [1.57, 4.71, 7.85, 10.99, 14.13, 17.27, 20.42, 23.56, 26.7, 29.84, 32.98, 36.12, 39.27, 42.41, 45.55, 48.69, 51.83, 54.97, 58.12, 61.26, 64.4, 67.54, 70.68, 73.82, 76.97, 80.11, 83.25, 86.39, 89.53, 92.68, 95.82, 98.96]
#
# period difference:
#  [3.1399999999999997, 3.1399999999999997, 3.1400000000000006, 3.1400000000000006, 3.139999999999999, 3.150000000000002, 3.139999999999997, 3.1400000000000006, 3.1400000000000006, 3.139999999999997, 3.1400000000000006, 3.1500000000000057, 3.1399999999999935, 3.1400000000000006, 3.1400000000000006, 3.1400000000000006, 3.1400000000000006, 3.1499999999999986, 3.1400000000000006, 3.1400000000000077, 3.1400000000000006, 3.1400000000000006, 3.1399999999999864, 3.1500000000000057, 3.1400000000000006, 3.1400000000000006, 3.1400000000000006, 3.1400000000000006, 3.1500000000000057, 3.1399999999999864, 3.1400000000000006]

# %%
model.ExactEuler()
